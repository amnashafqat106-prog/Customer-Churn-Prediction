# %%
# %%writefile README.md
# [markdown content here]
# Out:
# Overwriting README.md

# %%
with open("README.md", "w") as f:
    f.write("""[markdown content here]""")

# %%
# %%writefile README.md
# # Customer Churn Prediction - AI/ML Project
#
# ## Project Overview
# A machine learning web application that predicts customer churn risk with 79% accuracy.
#
# ## Features
# - Data analysis and visualization
# - Machine learning model with 79% accuracy
# - Streamlit web application
# - Real-time predictions
#
# ## Installation
# ```bash
# pip install -r requirements.txt
# streamlit run app.py
# Out:
# Overwriting README.md

# %%
import os

print("=== CURRENT FILES ===")
for file in os.listdir('.'):
    if file.endswith(('.py', '.md', '.txt', '.pkl')):
        print(f"📄 {file}")

print("\n=== FILE TYPES ===")
files_to_check = ['app.py', 'README.md', 'requirements.txt']
for file in files_to_check:
    if os.path.exists(file):
        with open(file, 'r', encoding='utf-8') as f:
            first_line = f.readline().strip()
        print(f"{file}: {first_line[:50]}...")
    else:
         print(f"{file}: ❌ MISSING")
# Out:
# === CURRENT FILES ===
# 📄 app file.py
# 📄 app.py
# 📄 churn_prediction_model.pkl
# 📄 dashboard.py
# 📄 heart_model.pkl
# 📄 import pandas as pd.py
# 📄 import streamlit as st.py
# 📄 model_columns.pkl
# 📄 pakistani_coach.py
# 📄 pip install openai plaid-python python-d.py
# 📄 pip install pandas.py
# 📄 pk code.py
# 📄 README.md
# 📄 requirements.txt
# 📄 scaler.pkl
# 📄 simple_app.py
# 📄 test_file.txt
# 📄 untitled.txt
#
# === FILE TYPES ===
# app.py: import streamlit as st...
# README.md: # Customer Churn Prediction - AI/ML Project...
# requirements.txt: streamlit>=1.28.0...
