# %%
# Create requirements.txt with all dependencies
requirements_content = '''streamlit>=1.28.0
pandas>=2.0.3
numpy>=1.24.3
scikit-learn>=1.3.0
matplotlib>=3.7.2
seaborn>=0.12.2
joblib>=1.3.2
'''

with open('requirements.txt', 'w') as f:
    f.write(requirements_content)

print("✅ requirements.txt created successfully!")
# Out:
# ✅ requirements.txt created successfully!

# %%
import os

print("=== FINAL FILE CHECK ===")
required_files = ['app.py', 'README.md', 'requirements.txt', 
                 'churn_prediction_model.pkl', 'model_columns.pkl']

all_good = True
for file in required_files:
    if os.path.exists(file):
        print(f"✅ {file} - READY")
    else:
        print(f"❌ {file} - MISSING")
        all_good = False

if all_good:
    print("\n🎉 ALL FILES READY! You can now upload to GitHub!")
else:
    print("\n⚠️  Some files are missing. Let me know which ones.")
# Out:
# === FINAL FILE CHECK ===
# ✅ app.py - READY
# ✅ README.md - READY
# ✅ requirements.txt - READY
# ✅ churn_prediction_model.pkl - READY
# ✅ model_columns.pkl - READY
#
# 🎉 ALL FILES READY! You can now upload to GitHub!
